# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import geopandas as gpd
import cartopy as cpy       
import matplotlib.pyplot as plt

print(" NumPy, Pandas, Seaborn, and scikit-learn loaded successfully!")
print(" GeoPandas version:", gpd.__version__)
print("Cartopy version:", cpy.__version__)

# simple ML test
X = np.array([[1], [2], [3]])
y = np.array([2, 4, 6])
model = LinearRegression().fit(X, y)
print(" ML test:", model.predict([[4]]))  

# simple map test
plt.figure(figsize=(3,2))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
plt.title("Mapping toolbox test (Cartopy working)")
plt.show()
# Out:
#  NumPy, Pandas, Seaborn, and scikit-learn loaded successfully!
#  GeoPandas version: 1.1.1
# Cartopy version: 0.25.0
#  ML test: [8.]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 21
#      19 # simple map test
#      20 plt.figure(figsize=(3,2))
# ---> 21 ax = plt.axes(projection=ccrs.PlateCarree())
#      22 ax.coastlines()
#      23 plt.title("Mapping toolbox test (Cartopy working)")
#
# NameError: name 'ccrs' is not defined
